# %% [markdown]
# # 02_DataQuality
#
# Este notebook verifica calidad de datos (valores faltantes y filas duplicadas) usando el conjunto completo de años con `load_all_years()`.

# %%
from src.data_loader.data_loader import load_all_years
from src.sampling.sample import random_sample
from src.quality.data_quality import check_missing_and_duplicates

# Cargar todos los años y tomar una muestra para rapidez
full_df = load_all_years()
sample = random_sample(full_df, n=1000)

issues = check_missing_and_duplicates(sample)
print('Data quality issues:', issues)
