# %% [markdown]
# # 08_Testing
#
# Este notebook muestra cómo ejecutar la suite de pruebas del proyecto usando **pytest**.
# Se asume que el entorno Docker está levantado y que el directorio `tests/` contiene los archivos de prueba.

# %%
# !pytest -q tests
