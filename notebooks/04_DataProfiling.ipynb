# %% [markdown]
# # 04_DataProfiling
#
# Este notebook genera estadísticas descriptivas básicas usando `src.profiling.profiling` sobre una muestra de los datos de todos los años.

# %%
from src.data_loader.data_loader import load_all_years
from src.sampling.sample import random_sample
from src.profiling.profiling import basic_profile
import json

# Cargar todos los años y muestrear 1000 filas
full_df = load_all_years()
sample = random_sample(full_df, n=1000)

profile = basic_profile(sample)
print(json.dumps(profile, indent=2))
