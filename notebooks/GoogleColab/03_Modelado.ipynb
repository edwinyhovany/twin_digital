# %% [markdown]
# # Modelo Predictivo

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

# %%
target='Pago'
features=['cluster'] # completar con edad, sexo, utilización y variables derivadas
train=df[df['Periodo']<=202312]
valid=df[df['Periodo']>=202401]
model=XGBRegressor(n_estimators=300,max_depth=6)
model.fit(train[features],train[target])
pred=model.predict(valid[features])
print(mean_absolute_error(valid[target],pred))
