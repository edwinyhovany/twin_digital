# %% [markdown]
# # Simulación de Escenarios

# %%
base=valid.copy()
base['pago_estimado']=model.predict(base[features])

# %%
esc1=valid.copy()
# modificar variables de seguimiento ambulatorio
esc1['pago_estimado']=model.predict(esc1[features])
