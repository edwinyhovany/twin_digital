# %% [markdown]
# # Fase 2 - EDA Diabetes

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# %%
ruta='/content/drive/MyDrive/diabetes/data/'
archivos=['COSTOS_PAGOS_DIABETES_2022.parquet','COSTOS_PAGOS_DIABETES_2023.parquet','COSTOS_PAGOS_DIABETES_2024.parquet','COSTOS_PAGOS_DIABETES_2025.parquet','COSTOS_PAGOS_DIABETES_2026.parquet']
df=pd.concat([pd.read_parquet(ruta+a) for a in archivos])
df.head()

# %%
df.info()
df.describe(include='all')
